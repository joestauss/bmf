# %%
from filmsets import *
from FilmCollectionExport import *

filmset = TestSet.long

detailed_collection = DetailedFilmCollection( filmset)
detailed_collection.scrape_all()
# Out:
# Creating thread 1.
# Creating thread 2.
# Creating thread 3.
# Creating thread 4.
# Creating thread 5.
# Creating thread 6.
# Creating thread 7.
# Creating thread 8.
# Creating thread 9.
# Creating thread 10.
# Creating thread 11.
# Creating thread 12.
# Creating thread 13.
# Creating thread 14.
# Creating thread 15.
# Creating thread 16.
# Creating thread 17.
# Creating thread 18.
# Creating thread 19.
# Creating thread 20.
# Creating thread 21.
# Creating thread 22.
# Creating thread 23.
# Creating thread 24.
# Creating thread 25.
# Creating thread 26.
# Creating thread 27.
# Creating thread 28.
# Creating thread 29.
# Creating thread 30.
# Creating thread 31.
# Creating thread 32.
# Creating thread 33.
# Creating thread 34.
# Creating thread 35.
# Creating thread 36.
# Creating thread 37.
# Creating thread 38.
# Creating thread 39.
# Creating thread 40.
# Creating thread 41.
# Creating thread 42.
# Creating thread 43.
# Creating thread 44.
# Creating thread 45.
# Creating thread 46.
# Creating thread 47.
# Creating thread 48.
# Creating thread 49.
# Creating thread 50.
# Creating thread 51.
# Creating thread 52.
# Creating thread 53.
# Creating thread 54.
# Creating thread 55.
# Creating thread 56.
# Creating thread 57.
# Creating thread 58.
# Creating thread 59.
# Creating thread 60.
# Creating thread 61.
# Creating thread 62.
# Creating thread 63.
# Creating thread 64.
# Creating thread 65.
# Creating thread 66.
# Creating thread 67.
# Creating thread 68.
# Creating thread 69.
# Creating thread 70.
# Creating thread 71.
# Creating thread 72.
# Creating thread 73.
# Creating thread 74.
# Creating thread 75.
# Creating thread 76.
# Creating thread 77.
# Creating thread 78.
# Creating thread 79.
# Creating thread 80.
# Waiting for 80 threads..
# Waiting for 79 threads..
# Waiting for 78 threads..
# Waiting for 77 threads..
# Waiting for 76 threads..
# Waiting for 75 threads..
# Waiting for 74 threads..
# Waiting for 73 threads..
# Waiting for 72 threads..
# Waiting for 71 threads..
# Waiting for 70 threads..
# Waiting for 69 threads..
# Waiting for 68 threads..
# Waiting for 67 threads..
# Waiting for 66 threads..
# Waiting for 65 threads..
# Waiting for 64 threads..
# Waiting for 63 threads..
# Waiting for 62 threads..
# Waiting for 61 threads..
# Waiting for 60 threads..
# Waiting for 59 threads..
# Waiting for 58 threads..
# Waiting for 57 threads..
# Waiting for 56 threads..
# Waiting for 55 threads..
# Waiting for 54 threads..
# Waiting for 53 threads..
# Waiting for 52 threads..
# Waiting for 51 threads..
# Waiting for 50 threads..
# Waiting for 49 threads..
# Waiting for 48 threads..
# Waiting for 47 threads..
# Waiting for 46 threads..
# Waiting for 45 threads..
# Waiting for 44 threads..
# Waiting for 43 threads..
# Waiting for 42 threads..
# Waiting for 41 threads..
# Waiting for 40 threads..
# Waiting for 39 threads..
# Waiting for 38 threads..
# Waiting for 37 threads..
# Waiting for 36 threads..
# Waiting for 35 threads..
# Waiting for 34 threads..
# Waiting for 33 threads..
# Waiting for 32 threads..
# Waiting for 31 threads..
# Waiting for 30 threads..
# Waiting for 29 threads..
# Waiting for 28 threads..
# Waiting for 27 threads..
# Waiting for 26 threads..
# Waiting for 25 threads..
# Waiting for 24 threads..
# Waiting for 23 threads..
# Waiting for 22 threads..
# Waiting for 21 threads..
# Waiting for 20 threads..
# Waiting for 19 threads..
# Waiting for 18 threads..
# Waiting for 17 threads..
# Waiting for 16 threads..
# Waiting for 15 threads..
# Waiting for 14 threads..
# Waiting for 13 threads..
# Waiting for 12 threads..
# Waiting for 11 threads..
# Waiting for 10 threads..
# Waiting for 9 threads..
# Waiting for 8 threads..
# Waiting for 7 threads..
# Waiting for 6 threads..
# Waiting for 5 threads..
# Waiting for 4 threads..
# Waiting for 3 threads..
# Waiting for 2 threads..
# Waiting for 1 threads..

# %%
print( BaseSQLExport( detailed_collection))
# Out:
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0058333", "The Masque of the Red Death", 1964);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0146336", "Urban Legend", 1998);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0075005", "The Omen", 1976);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0024368", "Mystery of the Wax Museum", 1933);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0195714", "Final Destination", 2000);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0397065", "House of Wax", 2005);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0053459", "Les yeux sans visage", 1960);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0827782", "Return to House on Haunted Hill", 2007);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0058620", "Strait-Jacket", 1964);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0097368", "The Fly II", 1989);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0052207", "The Snorkel", 1958);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0056552", "Tales of Terror", 1962);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0051418", "The Blob", 1958);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0042376", "The Damned Don't Cry", 1950);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0119345", "I Know What You Did Last Summer", 1997);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0056943", "The Comedy of Terrors", 1963);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0059297", "I Saw What You Did", 1965);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0054988", "Homicidal", 1961);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0036104", "The Leopard Man", 1943);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0171363", "The Haunting", 1999);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0192731", "Urban Legends: Final Cut", 2000);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0034587", "Cat People", 1942);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0120627", "Carnival of Souls", 1998);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0455760", "Dead Silence", 2007);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0053925", "House of Usher", 1960);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0059821", "The Tomb of Ligeia", 1964);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0482606", "The Strangers", 2008);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0185371", "House on Haunted Hill", 1999);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0056606", "Tower of London", 1962);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0070917", "The Wicker Man", 1973);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0051622", "The Fly", 1958);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0042544", "Harriet Craig", 1950);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0036341", "The Seventh Victim", 1943);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt1262416", "Scream 4", 2011);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0028478", "The Walking Dead", 1936);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0790686", "Mirrors", 2008);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0024188", "Island of Lost Souls", 1932);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0080516", "The Changeling", 1980);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0053363", "The Tingler", 1959);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0059096", "Della", 1965);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0058700", "The Last Man on Earth", 1964);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0057129", "The Haunting", 1963);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0055018", "The Innocents", 1961);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0055505", "Scream of Fear", 1961);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0055830", "Carnival of Souls", 1962);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0064747", "The Oblong Box", 1969);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0043456", "The Day the Earth Stood Still", 1951);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0036027", "I Walked with a Zombie", 1943);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0057379", "The Old Dark House", 1963);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0056368", "Premature Burial", 1962);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0037635", "Dead of Night", 1945);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0288477", "Ghost Ship", 2002);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0076162", "Hausu", 1977);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0130018", "I Still Know What You Did Last Summer", 1998);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0900357", "Boogeyman 2", 2007);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0451957", "Urban Legends: Bloody Mary", 2005);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0069995", "Don't Look Now", 1973);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0068503", "Dr. Phibes Rises Again", 1972);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0454841", "The Hills Have Eyes", 2006);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0059646", "Repulsion", 1965);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0045888", "House of Wax", 1953);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0057449", "The Raven", 1963);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0052602", "The Bat", 1959);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0309593", "Final Destination 2", 2003);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0055304", "Pit and the Pendulum", 1961);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0076786", "Suspiria", 1977);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0026685", "Mark of the Vampire", 1935);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0058403", "The Night Walker", 1964);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0057608", "Twice-Told Tales", 1963);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0077745", "Invasion of the Body Snatchers", 1978);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0083722", "Cat People", 1982);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0051744", "House on Haunted Hill", 1959);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0295700", "Wrong Turn", 2003);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0026912", "The Raven", 1935);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0056725", "Zotz!", 1962);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0056993", "Diary of a Madman", 1963);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0053219", "Return of the Fly", 1959);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0057128", "The Haunted Palace", 1963);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0263488", "Jeepers Creepers", 2001);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0026663", "Mad Love", 1935);

# %%
print( TaglineSQLExport( detailed_collection))
# Out:
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0058333", "The Masque of the Red Death", 1964);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0146336", "Urban Legend", 1998);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0075005", "The Omen", 1976);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0024368", "Mystery of the Wax Museum", 1933);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0195714", "Final Destination", 2000);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0397065", "House of Wax", 2005);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0053459", "Les yeux sans visage", 1960);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0827782", "Return to House on Haunted Hill", 2007);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0058620", "Strait-Jacket", 1964);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0097368", "The Fly II", 1989);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0052207", "The Snorkel", 1958);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0056552", "Tales of Terror", 1962);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0051418", "The Blob", 1958);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0042376", "The Damned Don't Cry", 1950);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0119345", "I Know What You Did Last Summer", 1997);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0056943", "The Comedy of Terrors", 1963);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0059297", "I Saw What You Did", 1965);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0054988", "Homicidal", 1961);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0036104", "The Leopard Man", 1943);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0171363", "The Haunting", 1999);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0192731", "Urban Legends: Final Cut", 2000);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0034587", "Cat People", 1942);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0120627", "Carnival of Souls", 1998);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0455760", "Dead Silence", 2007);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0053925", "House of Usher", 1960);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0059821", "The Tomb of Ligeia", 1964);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0482606", "The Strangers", 2008);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0185371", "House on Haunted Hill", 1999);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0056606", "Tower of London", 1962);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0070917", "The Wicker Man", 1973);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0051622", "The Fly", 1958);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0042544", "Harriet Craig", 1950);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0036341", "The Seventh Victim", 1943);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt1262416", "Scream 4", 2011);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0028478", "The Walking Dead", 1936);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0790686", "Mirrors", 2008);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0024188", "Island of Lost Souls", 1932);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0080516", "The Changeling", 1980);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0053363", "The Tingler", 1959);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0059096", "Della", 1965);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0058700", "The Last Man on Earth", 1964);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0057129", "The Haunting", 1963);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0055018", "The Innocents", 1961);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0055505", "Scream of Fear", 1961);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0055830", "Carnival of Souls", 1962);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0064747", "The Oblong Box", 1969);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0043456", "The Day the Earth Stood Still", 1951);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0036027", "I Walked with a Zombie", 1943);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0057379", "The Old Dark House", 1963);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0056368", "Premature Burial", 1962);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0037635", "Dead of Night", 1945);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0288477", "Ghost Ship", 2002);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0076162", "Hausu", 1977);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0130018", "I Still Know What You Did Last Summer", 1998);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0900357", "Boogeyman 2", 2007);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0451957", "Urban Legends: Bloody Mary", 2005);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0069995", "Don't Look Now", 1973);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0068503", "Dr. Phibes Rises Again", 1972);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0454841", "The Hills Have Eyes", 2006);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0059646", "Repulsion", 1965);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0045888", "House of Wax", 1953);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0057449", "The Raven", 1963);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0052602", "The Bat", 1959);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0309593", "Final Destination 2", 2003);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0055304", "Pit and the Pendulum", 1961);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0076786", "Suspiria", 1977);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0026685", "Mark of the Vampire", 1935);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0058403", "The Night Walker", 1964);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0057608", "Twice-Told Tales", 1963);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0077745", "Invasion of the Body Snatchers", 1978);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0083722", "Cat People", 1982);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0051744", "House on Haunted Hill", 1959);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0295700", "Wrong Turn", 2003);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0026912", "The Raven", 1935);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0056725", "Zotz!", 1962);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0056993", "Diary of a Madman", 1963);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0053219", "Return of the Fly", 1959);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0057128", "The Haunted Palace", 1963);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0263488", "Jeepers Creepers", 2001);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0026663", "Mad Love", 1935);
#
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0058333", "Horror has a face.", 0);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0058333", "Look into this face", 1);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0146336", "It Happened To Someone Who Knows Someone You Know... You're Next.", 2);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0146336", "Just because it didn't happen, doesn't mean it can't", 3);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0075005", "Those who foretold it are dead.  Those who can stop it are in grave danger.", 4);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0075005", "It is the greatest mystery of all because no human being will ever solve it.", 5);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0024368", "Warner Bros.' Supreme Thriller", 6);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0024368", "Another Lovely Woman Vanished from the Earth!...Another Beauty Molded to His Desire!", 7);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0195714", "Face Your Deepest Fears... Before They Face You.", 8);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0195714", "Are you ready to match wits with the Grim Reaper?", 9);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0397065", "Gejagt. Ermordet. Zur Schau gestellt. (Hunted.Murdered.Displayed.)", 10);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0397065", "Prey. Slay. Display.", 11);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0053459", "Beautiful women were the victims of his FIENDISH FACIALS!!! [American retitled and dubbed version poster]", 12);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0827782", "The Welcome Mat is Out. Do Come In", 13);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0058620", "WARNING! 'Strait-Jacket' vividly depicts ax murders!", 14);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0058620", "Keep Saying to Yourself - It's Only a Film...It's Only a Film...It's Only a Film...", 15);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0097368", "Like father, like son.", 16);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0097368", "A new generation of terror!", 17);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0052207", "Teenage Girl Vs. ... Killer-With-A-Gimmick!", 18);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0056552", "A Trilogy of Shock and Horror!", 19);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0051418", "Bloated with the blood of its victims!", 20);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0051418", "It crawls.... It creeps.... It eats you alive!", 21);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0042376", "Warner Bros.' Flaming Stars of 'Flamingo Road' Meet in Scarlet Shadows Again!", 22);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0042376", "'Call me CHEAP?' Nothing's Cheap When You Pay the Price She's Paying!", 23);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0119345", "The Mistake They Made, Is Coming Back To Haunt Them.", 24);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0119345", "Nobody Saw Him Step Out. Nobody Saw Them Kill Him. Nobody Could Imagine The Terror To Follow.", 25);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0056943", "They put new life in the undertaking business!", 26);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0056943", "Where the GHOULS are...is where the FUN is!", 27);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0059297", "You May Be the Target... of the Next Phone Call...", 28);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0059297", "William Castle warns you: This is a motion picture about UXORICIDE!", 29);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0054988", "SPECIAL 'FRIGHT BREAK' * There will be a special FRIGHT BREAK during the showing of 'Homicidal.' Can your heart stand the challenge when the clock starts the COUNTDOWN?", 30);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0054988", "THE PICTURE WITH A 'FRIGHT BREAK!'", 31);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0036104", "A shriek in the night--another victim torn to pieces by claw and fang! Is it man-like beast or beast-like man that picks only beauty as prey--and why?", 32);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0036104", "Don't Be Afraid To Know the Truth about the Monster That Killed For a Thrill!", 33);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0171363", "There once was a house, a bright happy home. Then something bad happened, and now it sits all alone. These (pillars) are its bones. These (walls) are its skin. These (windows) are its eyes. WON'T Y...", 34);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0171363", "Some houses are born bad.", 35);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0192731", "Legends never die", 36);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0192731", "This Fall, Legends, Never, Die.", 37);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0034587", "She Was Marked With The Curse Of Those Who Slink And Court And Kill By Night!", 38);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0034587", "The most terrifying menace of them all!", 39);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0120627", "Enter at your own risk!", 40);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0120627", "Enter... if you dare.", 41);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0455760", "You scream. You die.", 42);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0053925", "Mystery!...Terror!....Suspense! that out-shocks DRACULA and FRANKENSTEIN!", 43);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0053925", "Edgar Allan Poe's classic tale of the Ungodly...the Evil [House of Usher]", 44);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0059821", "CAT or WOMAN or a Thing Too Evil to Mention?", 45);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0059821", "His first wife is dead- but still a little CATTY!", 46);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0482606", "Because you were home.", 47);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0482606", "What would you do if this was happening to you?", 48);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0185371", "It's going to be a long night.", 49);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0185371", "Six strangers have the chance to make $1,000,000 EACH. All they have to do is make it through the night alive.", 50);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0056606", "You'll need someone to hang onto when you come face to face with the blood-chilling terrors in the tower!", 51);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0056606", "Mother England meets Father Terror!", 52);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt

# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0068503", "Run! Hide! Scream!", 101);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0454841", "Life is shorter than you think.", 102);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0454841", "Evil breeds.", 103);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0059646", "'A classic chiller of the 'Psycho' school!'", 104);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0059646", "From the Award-Winning Director of 'Knife In the Water'", 105);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0045888", "Warner Bros. bring you the first feature produced by a major studio in 3D...", 106);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0045888", "UNLIKE ANYTHING YOU'VE SEEN BEFORE! (original print ad - all caps)", 107);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0057449", "Wits and wizardry run a-fowl!", 108);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0057449", "The Macabre Masterpiece of Terror!", 109);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0052602", "P.S. After seeing 'The Bat' 7 out of 8 people will get cold feet tonight!", 110);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0052602", "When Someone SCREAMS ... It Will Be YOU!", 111);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0309593", "Even Death Gets A Sequel.", 112);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0309593", "Death may be closer than it appears.", 113);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0055304", "Betrayal cuts both ways!", 114);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0055304", "Until now no one has dared to film this ...... the most diabolical classic of all time!", 115);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0076786", "You can run from it. You can hide from it. You can't escape from it !!", 116);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0076786", "'Psycho' meets 'The Exorcist' with no holds barred", 117);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0026685", "NEITHER DEAD NOR ALIVE! Bizarre beings released from a weird half-world...the vampire and his cruel consort exert all their fiendish powers to enslave the soul of a beautiful girl (Print Ad- Cortla...", 118);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0026685", "WOMAN or VAMPIRE? Beautiful...alluring...hiding behind a dread mask of unearthly terror! The picture you'll love to shudder at! (Print Ad-Lodi News-Sentinel, ((Lodi, Calif.)) 26 July 1935)", 119);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0058403", "Do You Know You May Be Drawn to Dream of Sex...of Murder...of Secret Desires you're ashamed to admit when awake?", 120);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0058403", "WILLIAM CASTLE warns you that your dreams can make you a ...", 121);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0057608", "A trio of terror!", 122);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0077745", "Get some sleep", 123);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0077745", "From deep space... (advance one sheet)", 124);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0083722", "An erotic fantasy for the animal in us all.", 125);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0083722", "An erotic fantasy about the animal in us all.", 126);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0051744", "Consult your doctor!  Bring your seat belts!", 127);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0051744", "See it with someone with warm hands!", 128);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0295700", "Get Lost In These Woods and You're Dead Meat.", 129);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0295700", "Bad Stuff Happens When You're This Deep In The Woods.", 130);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0026912", "While this mad surgical genius chanted 'The Raven,' horrible screams rose up from his torture chamber below!", 131);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0026912", "The uncanny master of make-up in a new amazing shocker", 132);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0056725", "An absent-minded professor discovers a super-secret that will give you the greatest lift since love!", 133);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0056725", "The magic word for fun... ZOTZ!", 134);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0056993", "The Most Diabolical Pages Ever Written Become The Most Terrifying Motion Picture Ever Created!", 135);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0056993", "He upholds the law, except when he murders.", 136);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0053219", "The horror is back!", 137);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0053219", "HUMAN MONSTER created by atoms gone wild!", 138);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0057128", "What was the terrifying thing in the PIT that wanted women?", 139);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0057128", "A warlock's home is his castle...Forever!", 140);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0263488", "The Tastiest Horror Film of the Year!", 141);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0263488", "On this road in the middle of nowhere evil has found the perfect place to hide. It has a face. It has a home. And worst of all it has a plan.", 142);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0026663", "His love was pitiful...hopeless...madness...yet 'The Thing' tired of pity - and demanded love!", 143);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0026663", "Dead hands that live... and love... and kill!", 144);

# %%
print( ProductionSQLExport( detailed_collection))
# Out:
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0058333", "The Masque of the Red Death", 1964);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0146336", "Urban Legend", 1998);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0075005", "The Omen", 1976);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0024368", "Mystery of the Wax Museum", 1933);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0195714", "Final Destination", 2000);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0397065", "House of Wax", 2005);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0053459", "Les yeux sans visage", 1960);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0827782", "Return to House on Haunted Hill", 2007);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0058620", "Strait-Jacket", 1964);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0097368", "The Fly II", 1989);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0052207", "The Snorkel", 1958);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0056552", "Tales of Terror", 1962);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0051418", "The Blob", 1958);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0042376", "The Damned Don't Cry", 1950);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0119345", "I Know What You Did Last Summer", 1997);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0056943", "The Comedy of Terrors", 1963);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0059297", "I Saw What You Did", 1965);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0054988", "Homicidal", 1961);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0036104", "The Leopard Man", 1943);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0171363", "The Haunting", 1999);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0192731", "Urban Legends: Final Cut", 2000);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0034587", "Cat People", 1942);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0120627", "Carnival of Souls", 1998);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0455760", "Dead Silence", 2007);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0053925", "House of Usher", 1960);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0059821", "The Tomb of Ligeia", 1964);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0482606", "The Strangers", 2008);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0185371", "House on Haunted Hill", 1999);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0056606", "Tower of London", 1962);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0070917", "The Wicker Man", 1973);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0051622", "The Fly", 1958);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0042544", "Harriet Craig", 1950);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0036341", "The Seventh Victim", 1943);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt1262416", "Scream 4", 2011);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0028478", "The Walking Dead", 1936);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0790686", "Mirrors", 2008);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0024188", "Island of Lost Souls", 1932);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0080516", "The Changeling", 1980);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0053363", "The Tingler", 1959);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0059096", "Della", 1965);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0058700", "The Last Man on Earth", 1964);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0057129", "The Haunting", 1963);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0055018", "The Innocents", 1961);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0055505", "Scream of Fear", 1961);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0055830", "Carnival of Souls", 1962);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0064747", "The Oblong Box", 1969);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0043456", "The Day the Earth Stood Still", 1951);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0036027", "I Walked with a Zombie", 1943);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0057379", "The Old Dark House", 1963);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0056368", "Premature Burial", 1962);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0037635", "Dead of Night", 1945);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0288477", "Ghost Ship", 2002);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0076162", "Hausu", 1977);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0130018", "I Still Know What You Did Last Summer", 1998);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0900357", "Boogeyman 2", 2007);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0451957", "Urban Legends: Bloody Mary", 2005);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0069995", "Don't Look Now", 1973);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0068503", "Dr. Phibes Rises Again", 1972);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0454841", "The Hills Have Eyes", 2006);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0059646", "Repulsion", 1965);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0045888", "House of Wax", 1953);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0057449", "The Raven", 1963);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0052602", "The Bat", 1959);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0309593", "Final Destination 2", 2003);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0055304", "Pit and the Pendulum", 1961);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0076786", "Suspiria", 1977);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0026685", "Mark of the Vampire", 1935);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0058403", "The Night Walker", 1964);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0057608", "Twice-Told Tales", 1963);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0077745", "Invasion of the Body Snatchers", 1978);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0083722", "Cat People", 1982);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0051744", "House on Haunted Hill", 1959);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0295700", "Wrong Turn", 2003);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0026912", "The Raven", 1935);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0056725", "Zotz!", 1962);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0056993", "Diary of a Madman", 1963);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0053219", "Return of the Fly", 1959);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0057128", "The Haunted Palace", 1963);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0263488", "Jeepers Creepers", 2001);
# INSERT INTO Movie (movie_id, movie_title, movie_year) VALUES ("tt0026663", "Mad Love", 1935);
#
# INSERT INTO Production (production_name, production_id) VALUES (0, "Alta Vista Productions");
# INSERT INTO Production (production_name, production_id) VALUES (1, "Phoenix Pictures");
# INSERT INTO Production (production_name, production_id) VALUES (2, "Original Film");
# INSERT INTO Production (production_name, production_id) VALUES (3, "Canal+ Droits Audiovisuels");
# INSERT INTO Production (production_name, production_id) VALUES (4, "Mace Neufeld Productions");
# INSERT INTO Production (production_name, production_id) VALUES (5, "Harvey Bernhard Productions");
# INSERT INTO Production (production_name, production_id) VALUES (6, "Twentieth Century Fox");
# INSERT INTO Production (production_name, production_id) VALUES (7, "Twentieth Century-Fox Productions");
# INSERT INTO Production (production_name, production_id) VALUES (8, "Warner Bros.");
# INSERT INTO Production (production_name, production_id) VALUES (9, "New Line Cinema");
# INSERT INTO Production (production_name, production_id) VALUES (10, "Hard Eight Pictures");
# INSERT INTO Production (production_name, production_id) VALUES (11, "Zide-Perry Productions");
# INSERT INTO Production (production_name, production_id) VALUES (12, "Dark Castle Entertainment");
# INSERT INTO Production (production_name, production_id) VALUES (13, "Village Roadshow Pictures");
# INSERT INTO Production (production_name, production_id) VALUES (14, "Lux Film");
# INSERT INTO Production (production_name, production_id) VALUES (15, "Champs-Élysées Productions");
# INSERT INTO Production (production_name, production_id) VALUES (16, "Warner Premiere");
# INSERT INTO Production (production_name, production_id) VALUES (17, "William Castle Productions");
# INSERT INTO Production (production_name, production_id) VALUES (18, "Brooksfilms");
# INSERT INTO Production (production_name, production_id) VALUES (19, "Columbia Pictures Corporation");
# INSERT INTO Production (production_name, production_id) VALUES (20, "Hammer Films");
# INSERT INTO Production (production_name, production_id) VALUES (21, "Clarion Films");
# INSERT INTO Production (production_name, production_id) VALUES (22, "Tonylyn Productions Inc.");
# INSERT INTO Production (production_name, production_id) VALUES (23, "Valley Forge Films");
# INSERT INTO Production (production_name, production_id) VALUES (24, "Fairview Productions");
# INSERT INTO Production (production_name, production_id) VALUES (25, "Mandalay Entertainment");
# INSERT INTO Production (production_name, production_id) VALUES (26, "Summer Knowledge LLC");
# INSERT INTO Production (production_name, production_id) VALUES (27, "Universal Pictures");
# INSERT INTO Production (production_name, production_id) VALUES (28, "RKO Radio Pictures");
# INSERT INTO Production (production_name, production_id) VALUES (29, "Roth-Arnold Productions");
# INSERT INTO Production (production_name, production_id) VALUES (30, "Dreamworks Pictures");
# INSERT INTO Production (production_name, production_id) VALUES (31, "Trimark Pictures");
# INSERT INTO Production (production_name, production_id) VALUES (32, "Twisted Pictures");
# INSERT INTO Production (production_name, production_id) VALUES (33, "Evolution Entertainment");
# INSERT INTO Production (production_name, production_id) VALUES (34, "Vertigo Entertainment");
# INSERT INTO Production (production_name, production_id) VALUES (35, "Rogue Pictures");
# INSERT INTO Production (production_name, production_id) VALUES (36, "Mandate Pictures");
# INSERT INTO Production (production_name, production_id) VALUES (37, "Intrepid Pictures");
# INSERT INTO Production (production_name, production_id) VALUES (38, "Mad Hatter Entertainment");
# INSERT INTO Production (production_name, production_id) VALUES (39, "Edward Small Productions");
# INSERT INTO Production (production_name, production_id) VALUES (40, "British Lion Film Corporation");
# INSERT INTO Production (production_name, production_id) VALUES (41, "Regal Films");
# INSERT INTO Production (production_name, production_id) VALUES (42, "Columbia Pictures");
# INSERT INTO Production (production_name, production_id) VALUES (43, "Dimension Films");
# INSERT INTO Production (production_name, production_id) VALUES (44, "Corvus Corax Productions");
# INSERT INTO Production (production_name, production_id) VALUES (45, "The Weinstein Company");
# INSERT INTO Production (production_name, production_id) VALUES (46, "Outerbanks Entertainment");
# INSERT INTO Production (production_name, production_id) VALUES (47, "Prime Focus");
# INSERT INTO Production (production_name, production_id) VALUES (48, "Midnight Entertainment");
# INSERT INTO Production (production_name, production_id) VALUES (49, "New Regency Productions");
# INSERT INTO Production (production_name, production_id) VALUES (50, "Luna Pictures");
# INSERT INTO Production (production_name, production_id) VALUES (51, "Castel Film Romania");
# INSERT INTO Production (production_name, production_id) VALUES (52, "ASAF");
# INSERT INTO Production (production_name, production_id) VALUES (53, "Paramount Pictures");
# INSERT INTO Production (production_name, production_id) VALUES (54, "Chessman Park Productions");
# INSERT INTO Production (production_name, production_id) VALUES (55, "Four Star Productions");
# INSERT INTO Production (production_name, production_id) VALUES (56, "Associated Producers (API)");
# INSERT INTO Production (production_name, production_id) VALUES (57, "Produzioni La Regina");
# INSERT INTO Production (production_name, production_id) VALUES (58, "Argyle Enterprises");
# INSERT INTO Production (production_name, production_id) VALUES (59, "Achilles");
# INSERT INTO Production (production_name, production_id) VALUES (60, "Harcourt Productions");
# INSERT INTO Production (production_name, production_id) VALUES (61, "Centron Corporation");
# INSERT INTO Production (production_name, production_id) VALUES (62, "American International Pictures (AIP)");
# INSERT INTO Production (production_name, production_id) VALUES (63, "Roger Corman Productions");
# INSERT INTO Production (production_name, production_id) VALUES (64, "Ealing Studios");
# INSERT INTO Production (production_name, production_id) VALUES (65, "Ghost Ship Films Pty. Ltd.");
# INSERT INTO Production (production_name, production_id) VALUES (66, "NPV Entertainment");
# INSERT INTO Production (production_name, production_id) VALUES (67, "PSC");
# INSERT INTO Production (production_name, production_id) VALUES (68, "Toho Company");
# INSERT INTO Production (production_name, production_id) VALUES (69, "Estudios Churubusco Azteca S.A.");
# INSERT INTO Production (production_name, production_id) VALUES (70, "Ghost House Pictures");
# INSERT INTO Production (production_name, production_id) VALUES (71, "Destination Films");
# INSERT INTO Production (production_name, production_id) VALUES (72, "NPP Productions Inc.");
# INSERT INTO Production (production_name, production_id) VALUES (73, "Screen Gems");
# INSERT INTO Production (production_name, production_id) VALUES (74, "D.L.N. Ventures Partnership");
# INSERT INTO Production (production_name, production_id) VALUES (75, "Eldorado Films");
# INSERT INTO Production (production_name, production_id) VALUES (76, "Casey Productions");
# INSERT INTO Production (production_name, production_id) VALUES (77, "Amicus Productions");
# INSERT INTO Production (production_name, production_id) VALUES (78, "Craven-Maddalena Films");
# INSERT INTO Production (production_name, production_id) VALUES (79, "Major Studio Partners");
# INSERT INTO Production (production_name, production_id) VALUES (80, "Dune Entertainment");
# INSERT INTO Production (production_name, production_id) VALUES (81, "Tekli British Productions");
# INSERT INTO Production (production_name, production_id) VALUES (82, "Compton Films");
# INSERT INTO Production (production_name, production_id) VALUES (83, "Bryan Foy Productions");
# INSERT INTO Production (production_name, production_id) VALUES (84, "Liberty Pictures (IV)");
# INSERT INTO Production (production_name, production_id) VALUES (85, "Seda Spettacoli");
# INSERT INTO Production (production_name, production_id) VALUES (86, "Metro-Goldwyn-Mayer (MGM)");
# INSERT INTO Production (production_name, production_id) VALUES (87, "Robert E. Kent Productions");
# INSERT INTO Production (production_name, production_id) VALUES (88, "Solofilm");
# INSERT INTO Production (production_name, production_id) VALUES (89, "RKO Pictures");
# INSERT INTO Production (production_name, production_id) VALUES (90, "Summit Entertainment");
# INSERT INTO Production (production_name, production_id) VALUES (91, "Newmarket Capital Group");
# INSERT INTO Production (production_name, production_id) VALUES (92, "Media Cooperation One");
# INSERT INTO Production (production_name, production_id) VALUES (93, "Stan Winston Studio");
# INSERT INTO Production (production_name, production_id) VALUES (94, "DCP Wrong Turn Productions");
# INSERT INTO Production (production_name, production_id) VALUES (95, "Constantin Film");
# INSERT INTO Production (production_name, production_id) VALUES (96, "La Honda Productions");
# INSERT INTO Production (production_name, production_id) VALUES (97, "United Artists");
# INSERT INTO Production (production_name, production_id) VALUES (98, "Cinerenta Medienbeteiligungs KG");
# INSERT INTO Production (production_name, production_id) VALUES (99, "Cinerenta-Cinebeta");
# INSERT INTO Production (production_name, production_id) VALUES (100, "VCL Communications");
# INSERT INTO Production (production_name, production_id) VALUES (101, "American Zoetrope");
#
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0058333", 0);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0146336", 1);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0146336", 2);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0146336", 3);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0075005", 4);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0075005", 5);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0075005", 6);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0075005", 7);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0024368", 8);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0195714", 9);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0195714", 10);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0195714", 11);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0397065", 12);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0397065", 8);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0397065", 13);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0053459", 14);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0053459", 15);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0827782", 16);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0827782", 12);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0058620", 17);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0097368", 18);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0052207", 19);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0052207", 20);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0052207", 21);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0056552", 0);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0051418", 22);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0051418", 23);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0051418", 24);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0042376", 8);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0119345", 2);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt0119345", 25);
# INSERT INTO MovieProduction (movie_id, production_id) VALUES ("tt

# INSERT INTO Movie (movie_id, movie_title, movie_year, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0026912", "The Raven", 1935, 115000, Null, 61);
# INSERT INTO Movie (movie_id, movie_title, movie_year, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0056725", "Zotz!", 1962, Null, Null, 87);
# INSERT INTO Movie (movie_id, movie_title, movie_year, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0056993", "Diary of a Madman", 1963, 350000, Null, 96);
# INSERT INTO Movie (movie_id, movie_title, movie_year, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0053219", "Return of the Fly", 1959, 225000, Null, 80);
# INSERT INTO Movie (movie_id, movie_title, movie_year, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0057128", "The Haunted Palace", 1963, Null, Null, 87);
# INSERT INTO Movie (movie_id, movie_title, movie_year, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0263488", "Jeepers Creepers", 2001, 10000000, 59371303, 90);
# INSERT INTO Movie (movie_id, movie_title, movie_year, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0026663", "Mad Love", 1935, 257502, Null, 68);
#
# INSERT INTO Person (person_name, person_id) VALUES (0, "R. Wright Campbell");
# INSERT INTO Person (person_name, person_id) VALUES (1, "Charles Beaumont");
# INSERT INTO Person (person_name, person_id) VALUES (2, "Roger Corman");
# INSERT INTO Person (person_name, person_id) VALUES (3, "Silvio Horta");
# INSERT INTO Person (person_name, person_id) VALUES (4, "Jamie Blanks");
# INSERT INTO Person (person_name, person_id) VALUES (5, "David Seltzer");
# INSERT INTO Person (person_name, person_id) VALUES (6, "Richard Donner");
# INSERT INTO Person (person_name, person_id) VALUES (7, "Carl Erickson");
# INSERT INTO Person (person_name, person_id) VALUES (8, "Don Mullaly");
# INSERT INTO Person (person_name, person_id) VALUES (9, "Michael Curtiz");
# INSERT INTO Person (person_name, person_id) VALUES (10, "James Wong");
# INSERT INTO Person (person_name, person_id) VALUES (11, "Glen Morgan");
# INSERT INTO Person (person_name, person_id) VALUES (12, "Chad Hayes");
# INSERT INTO Person (person_name, person_id) VALUES (13, "Charles Belden");
# INSERT INTO Person (person_name, person_id) VALUES (14, "Jaume Collet-Serra");
# INSERT INTO Person (person_name, person_id) VALUES (15, "Jean Redon");
# INSERT INTO Person (person_name, person_id) VALUES (16, "Pierre Boileau");
# INSERT INTO Person (person_name, person_id) VALUES (17, "Georges Franju");
# INSERT INTO Person (person_name, person_id) VALUES (18, "Robb White");
# INSERT INTO Person (person_name, person_id) VALUES (19, "William Massa");
# INSERT INTO Person (person_name, person_id) VALUES (20, "Víctor García");
# INSERT INTO Person (person_name, person_id) VALUES (21, "Robert Bloch");
# INSERT INTO Person (person_name, person_id) VALUES (22, "William Castle");
# INSERT INTO Person (person_name, person_id) VALUES (23, "Jim Wheat");
# INSERT INTO Person (person_name, person_id) VALUES (24, "Mick Garris");
# INSERT INTO Person (person_name, person_id) VALUES (25, "Chris Walas");
# INSERT INTO Person (person_name, person_id) VALUES (26, "Peter Myers");
# INSERT INTO Person (person_name, person_id) VALUES (27, "Jimmy Sangster");
# INSERT INTO Person (person_name, person_id) VALUES (28, "Guy Green");
# INSERT INTO Person (person_name, person_id) VALUES (29, "Richard Matheson");
# INSERT INTO Person (person_name, person_id) VALUES (30, "Edgar Allan Poe");
# INSERT INTO Person (person_name, person_id) VALUES (31, "Kay Linaker");
# INSERT INTO Person (person_name, person_id) VALUES (32, "Theodore Simonson");
# INSERT INTO Person (person_name, person_id) VALUES (33, "Irvin S. Yeaworth Jr.");
# INSERT INTO Person (person_name, person_id) VALUES (34, "Russell S. Doughten Jr.");
# INSERT INTO Person (person_name, person_id) VALUES (35, "Jerome Weidman");
# INSERT INTO Person (person_name, person_id) VALUES (36, "Harold Medford");
# INSERT INTO Person (person_name, person_id) VALUES (37, "Vincent Sherman");
# INSERT INTO Person (person_name, person_id) VALUES (38, "Kevin Williamson");
# INSERT INTO Person (person_name, person_id) VALUES (39, "Lois Duncan");
# INSERT INTO Person (person_name, person_id) VALUES (40, "Jim Gillespie");
# INSERT INTO Person (person_name, person_id) VALUES (41, "Jacques Tourneur");
# INSERT INTO Person (person_name, person_id) VALUES (42, "Ursula Curtiss");
# INSERT INTO Person (person_name, person_id) VALUES (43, "William P. McGivern");
# INSERT INTO Person (person_name, person_id) VALUES (44, "Ardel Wray");
# INSERT INTO Person (person_name, person_id) VALUES (45, "Edward Dein");
# INSERT INTO Person (person_name, person_id) VALUES (46, "David Self");
# INSERT INTO Person (person_name, person_id) VALUES (47, "Shirley Jackson");
# INSERT INTO Person (person_name, person_id) VALUES (48, "Jan de Bont");
# INSERT INTO Person (person_name, person_id) VALUES (49, "Paul Harris Boardman");
# INSERT INTO Person (person_name, person_id) VALUES (50, "John Ottman");
# INSERT INTO Person (person_name, person_id) VALUES (51, "DeWitt Bodeen");
# INSERT INTO Person (person_name, person_id) VALUES (52, "Adam Grossman");
# INSERT INTO Person (person_name, person_id) VALUES (53, "John Clifford");
# INSERT INTO Person (person_name, person_id) VALUES (54, "Leigh Whannell");
# INSERT INTO Person (person_name, person_id) VALUES (55, "James Wan");
# INSERT INTO Person (person_name, person_id) VALUES (56, "Robert Towne");
# INSERT INTO Person (person_name, person_id) VALUES (57, "Bryan Bertino");
# INSERT INTO Person (person_name, person_id) VALUES (58, "Dick Beebe");
# INSERT INTO Person (person_name, person_id) VALUES (59, "William Malone");
# INSERT INTO Person (person_name, person_id) VALUES (60, "F. Amos Powell");
# INSERT INTO Person (person_name, person_id) VALUES (61, "Leo Gordon");
# INSERT INTO Person (person_name, person_id) VALUES (62, "Anthony Shaffer");
# INSERT INTO Person (person_name, person_id) VALUES (63, "Robin Hardy");
# INSERT INTO Person (person_name, person_id) VALUES (64, "James Clavell");
# INSERT INTO Person (person_name, person_id) VALUES (65, "George Langelaan");
# INSERT INTO Person (person_name, person_id) VALUES (66, "Kurt Neumann");
# INSERT INTO Person (person_name, person_id) VALUES (67, "James Gunn");
# INSERT INTO Person (person_name, person_id) VALUES (68, "Anne Froelich");
# INSERT INTO Person (person_name, person_id) VALUES (69, "Charles O'Neal");
# INSERT INTO Person (person_name, person_id) VALUES (70, "Mark Robson");
# INSERT INTO Person (person_name, person_id) VALUES (71, "Wes Craven");
# INSERT INTO Person (person_name, person_id) VALUES (72, "Peter Milne");
# INSERT INTO Person (person_name, person_id) VALUES (73, "Ewart Adamson");
# INSERT INTO Person (person_name, person_id) VALUES (74, "Alexandre Aja");
# INSERT INTO Person (person_name, person_id) VALUES (75, "Grégory Levasseur");
# INSERT INTO Person (person_name, person_id) VALUES (76, "Philip Wylie");
# INSERT INTO Person (person_name, person_id) VALUES (77, "Waldemar Young");
# INSERT INTO Person (person_name, person_id) VALUES (78, "Erle C. Kenton");
# INSERT INTO Person (person_name, person_id) VALUES (79, "William Gray");
# INSERT INTO Person (person_name, person_id) VALUES (80, "Russell Hunter");
# INSERT INTO Person (person_name, person_id) VALUES (81, "Peter Medak");
# INSERT INTO Person (person_name, person_id) VALUES (82, "Richard Alan Simmons");
# INSERT INTO Person (person_name, person_id) VALUES (83, "Robert Gist");
# INSERT INTO Person (person_name, person_id) VALUES (84, "William F. Leicester");
# INSERT INTO Person (person_name, person_id) VALUES (85, "Ubaldo Ragona");
# INSERT INTO Person (person_name, person_id) VALUES (86, "Sidney Salkow");
# INSERT INTO Person (person_name, person_id) VALUES (87, "Nelson Gidding");
# INSERT INTO Person (person_name, person_id) VALUES (88, "Robert Wise");
# INSERT INTO Person (person_name, person_id) VALUES (89, "John Mortimer");
# INSERT INTO Person (person_name, person_id) VALUES (90, "Henry James");
# INSERT INTO Person (person_name, person_id) VALUES (91, "Jack Clayton");
# INSERT INTO Person (person_name, person_id) VALUES (92, "Seth Holt");
# INSERT INTO Person (person_name, person_id) VALUES (93, "Herk Harvey");
# INSERT INTO Person (person_name, person_id) VALUES (94, "Lawrence Huntington");
# INSERT INTO Person (person_name, person_id) VALUES (95, "Gordon Hessler");
# INSERT INTO Person (person_name, person_id) VALUES (96, "Harry Bates");
# INSERT INTO Person (person_name, person_id) VALUES (97, "Edmund H. North");
# INSERT INTO Person (person_name, person_id) VALUES (98, "Curt Siodmak");
# INSERT INTO Person (person_name, person_id) VALUES (99, "J.B. Priestley");
# INSERT INTO Person (person_name, person_id) VALUES (100, "Robert Dillon");
# INSERT INTO Person (person_name, person_id) VALUES (101, "Ray Russell");
# INSERT INTO Person (person_name, person_id) VALUES (102, "Angus MacPhail");
# INSERT INTO Person (person_name, person_id) VALUES (103, "John Baines");
# INSERT INTO Person (person_name, person_id) VALUES (104, "Alberto Cavalcanti");
# INSERT INTO Person (person_name, person_id) VALUES (105, "Charles Crichton");
# INSERT INTO Person (person_name, person_id) VALUES (106, "Mark Hanlon");
# INSERT INTO Person (person_name, person_id) VALUES (107, "Steve Beck");
# INSERT INTO Person (person_name, person_id) VALUES (108, "Chigumi Ôbayashi");
# INSERT INTO Person (person_name, person_id) VALUES (109, "Chiho Katsura");
# INSERT INTO Person (person_name, person_id) VALUES (110, "Nobuhiko Ôbayashi");
# INSERT INTO Person (person_name, person_id) VALUES (111, "Trey Callaway");
# INSERT INTO Person (person_name, person_id) VALUES (112, "Danny Cannon");
# INSERT INTO Person (person_name, person_id) VALUES (113, "Eric Kripke");
# INSERT INTO Person (person_name, person_id) VALUES (114, "Brian Sieve");
# INSERT INTO Person (person_name, person_id) VALUES (115, "Jeff Betancourt");
# INSERT INTO Person (person_name, person_id) VALUES (116, "Dan Harris");
# INSERT INTO Person (person_name, person_id) VALUES (117, "Michael Dougherty");
# INSERT INTO Person (person_name, person_id) VALUES (118, "Mary Lambert");
# INSERT INTO Person (person_name, person_id) VALUES (119, "Daphne Du Maurier");
# INSERT INTO Person (person_name, person_id) VALUES (120, "Allan Scott");
# INSERT INTO Person (person_name, person_id) VALUES (121, "Nicolas Roeg");
# INSERT INTO Person (person_name, person_id) VALUES (122, "Robert Fuest");
# INSERT INTO Person (person_name, person_id) VALUES (123, "Robert Blees");
# INSERT INTO Person (person_name, person_id) VALUES (124, "Roman Polanski");
# INSERT INTO Person (person_name, person_id) VALUES (125, "Gérard Brach");
# INSERT INTO Person (person_name, person_id) VALUES (126, "Crane Wilbur");
# INSERT INTO Person (person_name, person_id) VALUES (127, "André De Toth");
# INSERT INTO Person (person_name, person_id) VALUES (128, "Eric Bress");
# INSERT INTO Person (person_name, person_id) VALUES (129, "J. Mackye Gruber");
# INSERT INTO Person (person_name, person_id) VALUES (130, "David R. Ellis");
# INSERT INTO Person (person_name, person_id) VALUES (131, "Daria Nicolodi");
# INSERT INTO Person (person_name, person_id) VALUES (132, "Dario Argento");
# INSERT INTO Person (person_name, person_id) VALUES (133, "Bernard Schubert");
# INSERT INTO Person (person_name, person_id) VALUES (134, "Guy Endore");
# INSERT INTO Person (person_name, person_id) VALUES (135, "Tod Browning");
# INSERT INTO Person (person_name, person_id) VALUES (136, "Robert E. Kent");
# INSERT INTO Person (person_name, person_id) VALUES (137, "Nathaniel Hawthorne");
# INSERT INTO Person (person_name, person_id) VALUES (138, "W.D. Richter");
# INSERT INTO Person (person_name, person_id) VALUES (139, "Jack Finney");
# INSERT INTO Person (person_name, person_id) VALUES (140, "Philip Kaufman");
# INSERT INTO Person (person_name, person_id) VALUES (141, "Alan Ormsby");
# INSERT INTO Person (person_name, person_id) VALUES (142, "Paul Schrader");
# INSERT INTO Person (person_name, person_id) VALUES (143, "Alan B. McElroy");
# INSERT INTO Person (person_name, person_id) VALUES (144, "Rob Schmidt");
# INSERT INTO Person (person_name, person_id) VALUES (145, "David Boehm");
# INSERT INTO Person (person_name, person_id) VALUES (146, "Lew Landers");
# INSERT INTO Person (person_name, person_id) VALUES (147, "Walter Karig");
# INSERT INTO Person (person_name, person_id) VALUES (148, "Guy de Maupassant");
# INSERT INTO Person (person_name, person_id) VALUES (149, "Reginald Le Borg");
# INSERT INTO Person (person_name, person_id) VALUES (150, "Edward Bernds");
# INSERT INTO Person (person_name, person_id) VALUES (151, "Victor Salva");
# INSERT INTO Person (person_name, person_id) VALUES (152, "Florence Crewe-Jones");
# INSERT INTO Person (person_name, person_id) VALUES (153, "Maurice Renard");
# INSERT INTO Person (person_name, person_id) VALUES (154, "Karl Freund");
#
# INSERT INTO RoleCode (role_name, role_code) VALUES ("Director", 0);
# INSERT INTO RoleCode (role_name, role_code) VALUES ("Writer", 1);
# INSERT INTO RoleCode (role_name, role_code) VALUES ("Actor", 2);
#
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0058333", 0, 0);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0058333", 0, 1);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0058333", 2, 2);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0146336", 0, 3);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0146336", 2, 4);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0075005", 0, 5);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0075005", 2, 6);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0024368", 0, 7);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0024368", 0, 8);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0024368", 2, 9);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0195714", 0, 10);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0195714", 0, 11);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0195714", 2, 10);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0397065", 0, 12);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0397065", 0, 13);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0397065", 2, 14);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0053459", 0, 15);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0053459", 0, 16);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0053459", 2, 17);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0827782", 0, 18);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0827782", 0, 19);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0827782", 2, 20);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0058620", 0, 21);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0058620", 2, 22);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0097368", 0, 23);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0097368", 0, 24);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0097368", 2, 25);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0052207", 0, 26);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0052207", 0, 27);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0052207", 2, 28);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0056552", 0, 29);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0056552", 0, 30);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0

# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0058403", 0, 21);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0058403", 2, 22);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0057608", 0, 136);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0057608", 0, 137);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0057608", 2, 86);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0077745", 0, 138);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0077745", 0, 139);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0077745", 2, 140);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0083722", 0, 141);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0083722", 0, 51);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0083722", 2, 142);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0051744", 0, 18);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0051744", 2, 22);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0295700", 0, 143);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0295700", 2, 144);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0026912", 0, 30);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0026912", 0, 145);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0026912", 2, 146);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0056725", 0, 147);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0056725", 0, 101);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0056725", 2, 22);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0056993", 0, 136);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0056993", 0, 148);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0056993", 2, 149);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0053219", 0, 150);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0053219", 0, 65);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0053219", 2, 150);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0057128", 0, 30);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0057128", 0, 1);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0057128", 2, 2);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0263488", 0, 151);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0263488", 2, 151);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0026663", 0, 152);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0026663", 0, 153);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0026663", 2, 154);
#
# INSERT INTO Genre (genre_name, genre_id) VALUES (0, "Horror");
# INSERT INTO Genre (genre_name, genre_id) VALUES (1, "Thriller");
# INSERT INTO Genre (genre_name, genre_id) VALUES (2, "Mystery");
# INSERT INTO Genre (genre_name, genre_id) VALUES (3, "Drama");
# INSERT INTO Genre (genre_name, genre_id) VALUES (4, "Fantasy");
# INSERT INTO Genre (genre_name, genre_id) VALUES (5, "Crime");
# INSERT INTO Genre (genre_name, genre_id) VALUES (6, "Sci-Fi");
# INSERT INTO Genre (genre_name, genre_id) VALUES (7, "Comedy");
# INSERT INTO Genre (genre_name, genre_id) VALUES (8, "Romance");
# INSERT INTO Genre (genre_name, genre_id) VALUES (9, "Film-Noir");
# INSERT INTO Genre (genre_name, genre_id) VALUES (10, "History");
#
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0058333", 0);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0146336", 0);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0146336", 1);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0146336", 2);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0075005", 0);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0024368", 0);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0024368", 1);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0024368", 2);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0195714", 0);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0195714", 1);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0397065", 0);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0397065", 1);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0053459", 0);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0053459", 3);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0827782", 4);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0827782", 5);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0827782", 0);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0827782", 1);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0827782", 2);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0058620", 0);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0058620", 3);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0058620", 1);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0097368", 0);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0097368", 6);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0097368", 3);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0052207", 0);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0052207", 2);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0052207", 1);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0052207", 5);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0056552", 0);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0056552", 1);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0056552", 7);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0056552", 2);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0051418", 0);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0051418", 6);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0042376", 3);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0042376", 8);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0042376", 5);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0042376", 9);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0042376", 1);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0119345", 0);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0119345", 2);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0056943", 0);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0056943", 7);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0059297", 0);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0059297", 1);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0059297", 5);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0054988", 0);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0054988", 1);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0054988", 2);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0036104", 0);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0036104", 1);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0171363", 0);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0171363", 4);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0171363", 1);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0171363", 2);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0192731", 0);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0192731", 1);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0192731", 2);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0034587", 0);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0034587", 4);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0034587", 1);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0120627", 0);
# INSERT INTO MovieGenre (movie_id, genre_id) VALUES ("tt0120627", 3);
# ...
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0171363", "Some houses are born bad.", 35);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0192731", "Legends never die", 36);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0192731", "This Fall, Legends, Never, Die.", 37);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0034587", "She Was Marked With The Curse Of Those Who Slink And Court And Kill By Night!", 38);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0034587", "The most terrifying menace of them all!", 39);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0120627", "Enter at your own risk!", 40);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0120627", "Enter... if you dare.", 41);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0455760", "You scream. You die.", 42);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0053925", "Mystery!...Terror!....Suspense! that out-shocks DRACULA and FRANKENSTEIN!", 43);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0053925", "Edgar Allan Poe's classic tale of the Ungodly...the Evil [House of Usher]", 44);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0059821", "CAT or WOMAN or a Thing Too Evil to Mention?", 45);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0059821", "His first wife is dead- but still a little CATTY!", 46);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0482606", "Because you were home.", 47);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0482606", "What would you do if this was happening to you?", 48);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0185371", "It's going to be a long night.", 49);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0185371", "Six strangers have the chance to make $1,000,000 EACH. All they have to do is make it through the night alive.", 50);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0

# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0451957", "Mary's Evil is Beyond Legend", 97);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0069995", "It's utter MADNESS!", 98);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0069995", "The Most Harrowing Experience That You May Ever Endure", 99);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0068503", "He lives!", 100);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0068503", "Run! Hide! Scream!", 101);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0454841", "Life is shorter than you think.", 102);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0454841", "Evil breeds.", 103);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0059646", "'A classic chiller of the 'Psycho' school!'", 104);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0059646", "From the Award-Winning Director of 'Knife In the Water'", 105);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0045888", "Warner Bros. bring you the first feature produced by a major studio in 3D...", 106);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0045888", "UNLIKE ANYTHING YOU'VE SEEN BEFORE! (original print ad - all caps)", 107);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0057449", "Wits and wizardry run a-fowl!", 108);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0057449", "The Macabre Masterpiece of Terror!", 109);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0052602", "P.S. After seeing 'The Bat' 7 out of 8 people will get cold feet tonight!", 110);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0052602", "When Someone SCREAMS ... It Will Be YOU!", 111);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0309593", "Even Death Gets A Sequel.", 112);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0309593", "Death may be closer than it appears.", 113);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0055304", "Betrayal cuts both ways!", 114);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0055304", "Until now no one has dared to film this ...... the most diabolical classic of all time!", 115);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0076786", "You can run from it. You can hide from it. You can't escape from it !!", 116);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0076786", "'Psycho' meets 'The Exorcist' with no holds barred", 117);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0026685", "NEITHER DEAD NOR ALIVE! Bizarre beings released from a weird half-world...the vampire and his cruel consort exert all their fiendish powers to enslave the soul of a beautiful girl (Print Ad- Cortla...", 118);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0026685", "WOMAN or VAMPIRE? Beautiful...alluring...hiding behind a dread mask of unearthly terror! The picture you'll love to shudder at! (Print Ad-Lodi News-Sentinel, ((Lodi, Calif.)) 26 July 1935)", 119);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0058403", "Do You Know You May Be Drawn to Dream of Sex...of Murder...of Secret Desires you're ashamed to admit when awake?", 120);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0058403", "WILLIAM CASTLE warns you that your dreams can make you a ...", 121);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0057608", "A trio of terror!", 122);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0077745", "Get some sleep", 123);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0077745", "From deep space... (advance one sheet)", 124);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0083722", "An erotic fantasy for the animal in us all.", 125);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0083722", "An erotic fantasy about the animal in us all.", 126);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0051744", "Consult your doctor!  Bring your seat belts!", 127);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0051744", "See it with someone with warm hands!", 128);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0295700", "Get Lost In These Woods and You're Dead Meat.", 129);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0295700", "Bad Stuff Happens When You're This Deep In The Woods.", 130);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0026912", "While this mad surgical genius chanted 'The Raven,' horrible screams rose up from his torture chamber below!", 131);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0026912", "The uncanny master of make-up in a new amazing shocker", 132);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0056725", "An absent-minded professor discovers a super-secret that will give you the greatest lift since love!", 133);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0056725", "The magic word for fun... ZOTZ!", 134);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0056993", "The Most Diabolical Pages Ever Written Become The Most Terrifying Motion Picture Ever Created!", 135);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0056993", "He upholds the law, except when he murders.", 136);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0053219", "The horror is back!", 137);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0053219", "HUMAN MONSTER created by atoms gone wild!", 138);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0057128", "What was the terrifying thing in the PIT that wanted women?", 139);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0057128", "A warlock's home is his castle...Forever!", 140);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0263488", "The Tastiest Horror Film of the Year!", 141);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0263488", "On this road in the middle of nowhere evil has found the perfect place to hide. It has a face. It has a home. And worst of all it has a plan.", 142);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0026663", "His love was pitiful...hopeless...madness...yet 'The Thing' tired of pity - and demanded love!", 143);
# INSERT INTO Tagline (movie_id, tagline_text, tagline_id) VALUES ("tt0026663", "Dead hands that live... and love... and kill!", 144);
