# %%
from filmsets import VincentPriceSets
import user_facing_classes as cls

filmset = VincentPriceSets.recursive_expansion_small_2_2

raw_movie_data = cls.BaseFilmCollection(filmset , VERBOSE=True)
# Out:
# Scraping from tt0051622...	(1 of 9)
# Scraping from tt0055304...	(2 of 9)
# Scraping from tt0064949...	(3 of 9)
# Scraping from tt0045888...	(4 of 9)
# Scraping from tt0051744...	(5 of 9)
# Scraping from tt0056943...	(6 of 9)
# Scraping from tt0056552...	(7 of 9)
# Scraping from tt0058333...	(8 of 9)
# Scraping from tt0064747...	(9 of 9)

# %%
normalized_movie_data = cls.BaseFilmDatabase( raw_movie_data)

print( normalized_movie_data.as_sql())
# Out:
# INSERT INTO Movie (movie_id, movie_title, movie_year, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0051744", "House on Haunted Hill", 1959, 200000, Null, 75);
# INSERT INTO Movie (movie_id, movie_title, movie_year, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0051622", "The Fly", 1958, 700000, 1501, 94);
# INSERT INTO Movie (movie_id, movie_title, movie_year, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0058333", "The Masque of the Red Death", 1964, Null, Null, 89);
# INSERT INTO Movie (movie_id, movie_title, movie_year, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0045888", "House of Wax", 1953, 1000000, 23750000, 88);
# INSERT INTO Movie (movie_id, movie_title, movie_year, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0056552", "Tales of Terror", 1962, Null, Null, 89);
# ...
